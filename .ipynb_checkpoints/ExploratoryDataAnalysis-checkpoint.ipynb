# %%
# import pandas and numpy library
import pandas as pd
import numpy as np
# import or load the json file and convert it to pandas dataframe
logins = pd.read_json('logins.json')

# %%
logins.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %%
logins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93142 entries, 0 to 93141
# Data columns (total 1 columns):
# login_time    93142 non-null datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 727.8 KB

# %%
logins = logins.sort_values('login_time')

# %%
logins.head()
# Out:
#            login_time
# 6 1970-01-01 20:12:16
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 3 1970-01-01 20:16:36
# 2 1970-01-01 20:16:37

# %%
logins = logins.join(pd.DataFrame({'y': logins.login_time.dt.year, 'm':logins.login_time.dt.month, 'd':logins.login_time.dt.day, 'h':logins.login_time.dt.hour, 'minu':logins.login_time.dt.minute, 'se':logins.login_time.dt.second}))

# %%
logins.head()
# Out:
#            login_time     y  m  d   h  minu  se
# 6 1970-01-01 20:12:16  1970  1  1  20    12  16
# 0 1970-01-01 20:13:18  1970  1  1  20    13  18
# 1 1970-01-01 20:16:10  1970  1  1  20    16  10
# 3 1970-01-01 20:16:36  1970  1  1  20    16  36
# 2 1970-01-01 20:16:37  1970  1  1  20    16  37

# %%
#logins['interval_time'] = np.where(logins['minu']<15, 0,np.where(logins['minu']<30, 15,np.where(logins['minu']<45, 30,np.where(logins['minu']<60, 45))))

# %%
logins_group = logins.groupby('login_time').count()
logins_group.head()
# Out:
#                      y  m  d  h  minu  se
# login_time
# 1970-01-01 20:12:16  1  1  1  1     1   1
# 1970-01-01 20:13:18  1  1  1  1     1   1
# 1970-01-01 20:16:10  1  1  1  1     1   1
# 1970-01-01 20:16:36  1  1  1  1     1   1
# 1970-01-01 20:16:37  1  1  1  1     1   1

# %%
logins['interval_time'] = np.where(logins['minu']<15, 0, np.where(logins['minu']<30,15,np.where(logins['minu']<45,30,np.where(logins['minu']<60,45,logins.minu))))

# %%
logins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93142 entries, 6 to 93140
# Data columns (total 8 columns):
# login_time       93142 non-null datetime64[ns]
# y                93142 non-null int64
# m                93142 non-null int64
# d                93142 non-null int64
# h                93142 non-null int64
# minu             93142 non-null int64
# se               93142 non-null int64
# interval_time    93142 non-null int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 8.9 MB

# %%
logins['date'] = pd.to_datetime(dict(year=logins.y,month=logins.m,day=logins.d))

# %%
logins.head()
# Out:
#            login_time     y  m  d   h  minu  se  interval_time       date
# 6 1970-01-01 20:12:16  1970  1  1  20    12  16              0 1970-01-01
# 0 1970-01-01 20:13:18  1970  1  1  20    13  18              0 1970-01-01
# 1 1970-01-01 20:16:10  1970  1  1  20    16  10             15 1970-01-01
