# %%
# import pandas and numpy library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import datetime as dt
import seaborn as sns
sns.set_style('whitegrid')

# %%
# import or load the json file and convert it to pandas dataframe
logins = pd.read_json('logins.json')

# %%
logins.head()
# Out:
#            login_time
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 2 1970-01-01 20:16:37
# 3 1970-01-01 20:16:36
# 4 1970-01-01 20:26:21

# %%
# check the infromation from the dataframe
logins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93142 entries, 0 to 93141
# Data columns (total 1 columns):
# login_time    93142 non-null datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 727.8 KB

# %%
# lets sort the dataframe
logins = logins.sort_values('login_time')

# %%
logins.head()
# Out:
#            login_time
# 6 1970-01-01 20:12:16
# 0 1970-01-01 20:13:18
# 1 1970-01-01 20:16:10
# 3 1970-01-01 20:16:36
# 2 1970-01-01 20:16:37

# %%
# join the dataframe with a new dataframe which include year month day hour minutes and second column
logins = logins.join(pd.DataFrame({'y': logins.login_time.dt.year, 'm':logins.login_time.dt.month, 'd':logins.login_time.dt.day, 'h':logins.login_time.dt.hour, 'minu':logins.login_time.dt.minute, 'se':logins.login_time.dt.second}))

# %%
logins.head()
# Out:
#            login_time     y  m  d   h  minu  se
# 6 1970-01-01 20:12:16  1970  1  1  20    12  16
# 0 1970-01-01 20:13:18  1970  1  1  20    13  18
# 1 1970-01-01 20:16:10  1970  1  1  20    16  10
# 3 1970-01-01 20:16:36  1970  1  1  20    16  36
# 2 1970-01-01 20:16:37  1970  1  1  20    16  37

# %%
logins.tail()
# Out:
#                login_time     y  m   d   h  minu  se
# 93136 1970-04-13 18:48:52  1970  4  13  18    48  52
# 93137 1970-04-13 18:50:19  1970  4  13  18    50  19
# 93139 1970-04-13 18:54:02  1970  4  13  18    54   2
# 93141 1970-04-13 18:54:23  1970  4  13  18    54  23
# 93140 1970-04-13 18:57:38  1970  4  13  18    57  38

# %%
#create a column named interval_time where we store if a login happened in 1st, 2nd, 3rd or 4th quarter of 15 minute time inteval
logins['interval_time'] = np.where(logins['minu']<15, 0, np.where(logins['minu']<30,15,np.where(logins['minu']<45,30,np.where(logins['minu']<60,45,logins.minu))))

# %%
logins.head()
# Out:
#            login_time     y  m  d   h  minu  se  interval_time
# 6 1970-01-01 20:12:16  1970  1  1  20    12  16              0
# 0 1970-01-01 20:13:18  1970  1  1  20    13  18              0
# 1 1970-01-01 20:16:10  1970  1  1  20    16  10             15
# 3 1970-01-01 20:16:36  1970  1  1  20    16  36             15
# 2 1970-01-01 20:16:37  1970  1  1  20    16  37             15

# %%
logins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93142 entries, 6 to 93140
# Data columns (total 8 columns):
# login_time       93142 non-null datetime64[ns]
# y                93142 non-null int64
# m                93142 non-null int64
# d                93142 non-null int64
# h                93142 non-null int64
# minu             93142 non-null int64
# se               93142 non-null int64
# interval_time    93142 non-null int64
# dtypes: datetime64[ns](1), int64(7)
# memory usage: 8.9 MB

# %%
# create a new column named data where we store datatime object with year/month/data
logins['date'] = pd.to_datetime(dict(year=logins.y,month=logins.m,day=logins.d))

# %%
logins.head()
# Out:
#            login_time     y  m  d   h  minu  se  interval_time       date
# 6 1970-01-01 20:12:16  1970  1  1  20    12  16              0 1970-01-01
# 0 1970-01-01 20:13:18  1970  1  1  20    13  18              0 1970-01-01
# 1 1970-01-01 20:16:10  1970  1  1  20    16  10             15 1970-01-01
# 3 1970-01-01 20:16:36  1970  1  1  20    16  36             15 1970-01-01
# 2 1970-01-01 20:16:37  1970  1  1  20    16  37             15 1970-01-01

# %%
# add hour as a time to the date column and create a new column
logins['date_interval_h'] = logins['date']+pd.to_timedelta(logins['h'], unit='h')

# %%
# add minute as time to the date_interval_h column and create a new column
logins['date_interval'] = logins['date_interval_h']+pd.to_timedelta(logins['interval_time'], unit='m')

# %%
logins.head()
# Out:
#            login_time     y  m  d   h  minu  se  interval_time       date  \
# 6 1970-01-01 20:12:16  1970  1  1  20    12  16              0 1970-01-01
# 0 1970-01-01 20:13:18  1970  1  1  20    13  18              0 1970-01-01
# 1 1970-01-01 20:16:10  1970  1  1  20    16  10             15 1970-01-01
# 3 1970-01-01 20:16:36  1970  1  1  20    16  36             15 1970-01-01
# 2 1970-01-01 20:16:37  1970  1  1  20    16  37             15 1970-01-01
#
#       date_interval_h       date_interval
# 6 1970-01-01 20:00:00 1970-01-01 20:00:00
# 0 1970-01-01 20:00:00 1970-01-01 20:00:00
# 1 1970-01-01 20:00:00 1970-01-01 20:15:00
# 3 1970-01-01 20:00:00 1970-01-01 20:15:00
# 2 1970-01-01 20:00:00 1970-01-01 20:15:00

# %% [markdown]
# # Grouping the data by datetime every 15 minute inteval

# %%
logins_interval_time = logins.groupby(['date_interval'])['login_time'].count()
df_time = pd.DataFrame(logins_interval_time)

# %%
df_time = pd.DataFrame(logins_interval_time)

# %%
df_time.head()
# Out:
#                      login_time
# date_interval
# 1970-01-01 20:00:00           2
# 1970-01-01 20:15:00           6
# 1970-01-01 20:30:00           9
# 1970-01-01 20:45:00           7
# 1970-01-01 21:00:00           1

# %%
# change the name of the column into number_of_logins
df_time.columns = ['number_of_logins']

# %%
# plot the graph
plt.figure(figsize=(40,10))
plt.xlabel('Date')
plt.ylabel('Number of logins')
plt.title('Time-series Graph for Number of Logins based on 15 minute time interval')
plt.plot(df_time)
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %% [markdown]
# There is no upward or downward trend.

# %%
# plot the graph
plt.xlabel('Date')
plt.ylabel('Number of logins')
plt.title('Time-series Graph for Number of Logins based on 15 minute time interval on January 1st')
plt.plot(df_time.loc['1970-01-01'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is for one day 1970-01-01

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Number of logins')
plt.title('Time-series Graph for Number of Logins based on 15 minute time interval on January 2nd')
plt.plot(df_time.loc['1970-01-02'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is for one day 1970-01-02

# %%
# plot the graph
plt.figure(figsize=(40,10))
plt.xlabel('Date')
plt.ylabel('Number of logins')
plt.title('Time-series Graph for Number of Logins based on 15 minute time interval for the month of January')
plt.plot(df_time.loc['1970-01-02':'1970-02-01'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is for the month of january

# %% [markdown]
# # Grouping the data by Date with hour to find total and average number of logins based on 15 minute time intervals every hour

# %%
# to group the data by date with hour and interval time
logins_interval_time = logins.groupby(['date_interval_h','interval_time'], as_index=False)['login_time'].count()
df_hourly = pd.DataFrame(logins_interval_time)

# %%
# check the data 
df_hourly.head()
# Out:
#       date_interval_h  interval_time  login_time
# 0 1970-01-01 20:00:00              0           2
# 1 1970-01-01 20:00:00             15           6
# 2 1970-01-01 20:00:00             30           9
# 3 1970-01-01 20:00:00             45           7
# 4 1970-01-01 21:00:00              0           1

# %%
#group the data by date with hour
df_hourly_avg = pd.DataFrame(df_hourly.groupby(['date_interval_h'])['login_time'].mean())

# %%
# change the name of the column into avg_hourly_number_of_logins
df_hourly_avg.columns = ['avg_hourly_number_of_logins']

# %%
#group the data by date with hour
df_hourly_total = pd.DataFrame(df_hourly.groupby(['date_interval_h'])['login_time'].sum())

# %%
# change the name of the column into total_hourly_number_of_logins
df_hourly_total.columns = ['total_hourly_number_of_logins']

# %%
# check the data 
df_hourly_avg.head()
# Out:
#                      avg_hourly_number_of_logins
# date_interval_h
# 1970-01-01 20:00:00                         6.00
# 1970-01-01 21:00:00                         3.00
# 1970-01-01 22:00:00                         5.25
# 1970-01-01 23:00:00                        14.50
# 1970-01-02 00:00:00                        13.25

# %%
# check the data 
df_hourly_total.head()
# Out:
#                      total_hourly_number_of_logins
# date_interval_h
# 1970-01-01 20:00:00                             24
# 1970-01-01 21:00:00                              9
# 1970-01-01 22:00:00                             21
# 1970-01-01 23:00:00                             58
# 1970-01-02 00:00:00                             53

# %%
# plot the graph
plt.figure(figsize=(40,10))
plt.xlabel('Date')
plt.ylabel('Average Number of logins')
plt.title('Average number of logins based on 15 minute interval every hour')
plt.plot(df_hourly_avg)
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Average Number of logins')
plt.title('Average number of logins based on 15 minute interval every hour for January 1st')
plt.plot(df_hourly_avg.loc['1970-01-01'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is for january 1st 1970

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Average Number of logins in 15 minutes interval')
plt.title('Average number of logins based on 15 minute interval every hour for January 2nd')
plt.plot(df_hourly_avg.loc['1970-01-02'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is for january 2nd 1970

# %%
# plot the graph
plt.figure(figsize=(40,10))
plt.xlabel('Date')
plt.ylabel('Average Number of logins')
plt.title('Average number of logins based on 15 minute interval every hour for January month')
plt.plot(df_hourly_avg.loc['1970-01-01':'1970-02-01'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is for the whole month of january

# %%
# plot the graph
plt.figure(figsize=(50,10))
plt.xlabel('Date')
plt.ylabel('Total Number of logins')
plt.title('Total number of logins in 15 minute interval every hour')
plt.plot(df_hourly_total)
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Total Number of logins')
plt.title('Total number of logins based on 15 minute interval every hour for January 1st')
plt.plot(df_hourly_total.loc['1970-01-01'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %% [markdown]
# The data is very small in size to interpret.

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Total Number of logins')
plt.title('Total number of logins based on 15 minute interval every hour for January 2nd')
plt.plot(df_hourly_total.loc['1970-01-02'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %%
# plot the graph
plt.figure(figsize=(40,10))
plt.xlabel('Date')
plt.ylabel('Total Number of logins')
plt.title('Total number of logins based on 15 minute interval every hour for month of January')
plt.plot(df_hourly_total.loc['1970-01-01':'1970-02-01'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %% [markdown]
# The graph does not show upward or downward trend.

# %% [markdown]
# # Group the data by date to find total and average number of logins every day based on 15 minute time intervals

# %%
# to group the data by date hour and interval time
logins_interval_time = logins.groupby(['date','h','interval_time'], as_index=False)['login_time'].count()
df_day = pd.DataFrame(logins_interval_time)

# %%
df_day.head()
# Out:
#         date   h  interval_time  login_time
# 0 1970-01-01  20              0           2
# 1 1970-01-01  20             15           6
# 2 1970-01-01  20             30           9
# 3 1970-01-01  20             45           7
# 4 1970-01-01  21              0           1

# %%
#group the data by date with hour
df_day_avg = pd.DataFrame(df_day.groupby(['date'])['login_time'].mean())

# %%
# change the name of the column into number_of_logins
df_day_avg.columns = ['avg_daily_number_of_logins']

# %%
#group the data by date with hour
df_day_total = pd.DataFrame(df_day.groupby(['date'])['login_time'].sum())

# %%
# change the name of the column into number_of_logins
df_day_total.columns = ['total_daily_number_of_logins']

# %%
df_day_avg.head()
# Out:
#             avg_daily_number_of_logins
# date
# 1970-01-01                    7.466667
# 1970-01-02                    7.322581
# 1970-01-03                    8.526882
# 1970-01-04                    8.294737
# 1970-01-05                    4.989130

# %%
df_day_total.head()
# Out:
#             total_daily_number_of_logins
# date
# 1970-01-01                           112
# 1970-01-02                           681
# 1970-01-03                           793
# 1970-01-04                           788
# 1970-01-05                           459

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Daily Average Number of logins')
plt.plot(df_day_avg)
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %% [markdown]
# This graph shows us a slight upward trend.

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Daily Average Number of logins')
plt.plot(df_day_avg.loc['1970-01-01':'1970-02-01'])
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is for the month of January

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Daily Total Number of logins')
plt.plot(df_day_total)
plt.xticks(rotation=90)
plt.tight_layout()
# the graph is noisy and difficult to interpret

# %% [markdown]
# The graph shows us a slight upward trend.

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Date')
plt.ylabel('Daily Total Number of logins')
plt.plot(df_day_total.loc['1970-01-01':'1970-02-01'])
plt.tight_layout()
# the graph is for the month of January

# %% [markdown]
# Data Quality issues:
#
# For the month of January, The login informations for

# %%
# Create a new dataframe to group the data by hour, day of week and month.
df_number_of_logins = df_time.reset_index()

# %%
# check the dataframe
df_number_of_logins.head()
# Out:
#         date_interval  number_of_logins
# 0 1970-01-01 20:00:00                 2
# 1 1970-01-01 20:15:00                 6
# 2 1970-01-01 20:30:00                 9
# 3 1970-01-01 20:45:00                 7
# 4 1970-01-01 21:00:00                 1

# %%
# join the dataframe with a new dataframe which include year month day hour and minutes column
df_number_of_logins = df_number_of_logins.join(pd.DataFrame({'y': df_number_of_logins.date_interval.dt.year, 'm':df_number_of_logins.date_interval.dt.month, 'd':df_number_of_logins.date_interval.dt.day, 'h':df_number_of_logins.date_interval.dt.hour, 'minu':df_number_of_logins.date_interval.dt.minute}))

# %%
# check the dataframe
df_number_of_logins.head()
# Out:
#         date_interval  number_of_logins     y  m  d   h  minu
# 0 1970-01-01 20:00:00                 2  1970  1  1  20     0
# 1 1970-01-01 20:15:00                 6  1970  1  1  20    15
# 2 1970-01-01 20:30:00                 9  1970  1  1  20    30
# 3 1970-01-01 20:45:00                 7  1970  1  1  20    45
# 4 1970-01-01 21:00:00                 1  1970  1  1  21     0

# %% [markdown]
# # Login Pattern by Hour

# %%
# Goup the data by hour to find out the average hourly logins
df_hourly_avg_logins = df_number_of_logins.groupby('h')['number_of_logins'].mean().reset_index()

# %%
# check the dataframe 
df_hourly_avg_logins
# Out:
#      h  number_of_logins
# 0    0         14.688725
# 1    1         15.482843
# 2    2         14.356436
# 3    3         12.017413
# 4    4         12.744304
# 5    5          8.226257
# 6    6          3.780731
# 7    7          2.383041
# 8    8          2.486322
# 9    9          3.986945
# 10  10          7.640898
# 11  11         14.283251
# 12  12         12.166667
# 13  13          8.850490
# 14  14          8.397059
# 15  15          7.614035
# 16  16          7.097744
# 17  17          6.541772
# 18  18          7.394541
# 19  19          8.169192
# 20  20         10.105911
# 21  21         13.815725
# 22  22         16.233415
# 23  23         14.848039

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Hours')
plt.ylabel('Average Number of logins')
plt.title('Hourly Average Number of Logins')
plt.plot(df_hourly_avg_logins)
plt.tight_layout()

# %% [markdown]
# The line plot shows us that the peak hours are at midnight to 1 am. Then the number of logins drops until 7am. At 7am to 8am has the lowest number of average logins. Then, The average number of logins picks up from h

# %% [markdown]
# # Logins Pattern by Day of Week

# %%
import calendar
df_number_of_logins['day_of_week'] = df_number_of_logins['date_interval'].apply(lambda x: x.weekday()) # get the weekday index, between 0 and 6
df_number_of_logins['day_of_week'] = df_number_of_logins['day_of_week'].apply(lambda x: calendar.day_name[x])
df_number_of_logins.head()
# Out:
#         date_interval  number_of_logins     y  m  d   h  minu day_of_week
# 0 1970-01-01 20:00:00                 2  1970  1  1  20     0    Thursday
# 1 1970-01-01 20:15:00                 6  1970  1  1  20    15    Thursday
# 2 1970-01-01 20:30:00                 9  1970  1  1  20    30    Thursday
# 3 1970-01-01 20:45:00                 7  1970  1  1  20    45    Thursday
# 4 1970-01-01 21:00:00                 1  1970  1  1  21     0    Thursday

# %%
# Group the data by day_of_week to find out the average number of logins
df_day_of_week_avg_logins = df_number_of_logins.groupby('day_of_week')['number_of_logins'].mean().reset_index()

# %%
# check the dataframe
df_day_of_week_avg_logins.sort_values('day_of_week')
# Out:
#   day_of_week  number_of_logins
# 0      Friday         10.893983
# 1      Monday          6.535556
# 2    Saturday         13.771855
# 3      Sunday         12.811707
# 4    Thursday          9.336456
# 5     Tuesday          7.396648
# 6   Wednesday          8.102665

# %%
sorter = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
sorterIndex = dict(zip(sorter,range(len(sorter))))
sorterIndex
# Out:
# {'Sunday': 0,
#  'Monday': 1,
#  'Tuesday': 2,
#  'Wednesday': 3,
#  'Thursday': 4,
#  'Friday': 5,
#  'Saturday': 6}

# %%
df_day_of_week_avg_logins['day_id'] = df_day_of_week_avg_logins['day_of_week'].map(sorterIndex)
df_day_of_week_avg_logins.sort_values('day_id', inplace=True)
df_day_of_week_avg_logins
# Out:
#   day_of_week  number_of_logins  day_id
# 3      Sunday         12.811707       0
# 1      Monday          6.535556       1
# 5     Tuesday          7.396648       2
# 6   Wednesday          8.102665       3
# 4    Thursday          9.336456       4
# 0      Friday         10.893983       5
# 2    Saturday         13.771855       6

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Day of Week')
plt.ylabel('Average Number of logins')
plt.title('Day of Week Average Number of Logins')
sns.barplot(data=df_day_of_week_avg_logins,x='day_of_week',y='number_of_logins')
plt.tight_layout()

# %% [markdown]
# # Login Pattern by Month

# %%
# Group the data by month to find out the average monthly logins
df_monthly_avg_logins = df_number_of_logins.groupby('m')['number_of_logins'].mean().reset_index()

# %%
df_monthly_avg_logins.head()
# Out:
#    m  number_of_logins
# 0  1          7.703663
# 1  2          9.630367
# 2  3         11.750174
# 3  4         11.331376

# %%
# plot the graph
plt.figure(figsize=(10,10))
plt.xlabel('Months')
plt.ylabel('Average Number of logins')
plt.title('Monthly Average Number of Logins')
sns.lineplot(data=df_monthly_avg_logins, x='m', y='number_of_logins')
plt.tight_layout()
